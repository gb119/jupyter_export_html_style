# %% [markdown]
# # Example Notebook with Custom Styles
#
# This notebook demonstrates the use of custom cell styles via metadata.

# %%
# This cell has a custom orange border and background
print('Hello, styled world!')

# %%
# This cell has no custom style
x = 42
print(f'The answer is {x}')

# %% [markdown]
# ## Styled Markdown Cell
#
# This markdown cell has a purple gradient background.
